# %% [markdown]
# <a href="https://colab.research.google.com/github/Akashkunwar/dscodes/blob/master/cov_vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import pandas as pd
import numpy as np
import os
import opendatasets as od

# %%
url = "https://www.kaggle.com/kunwarakash/covid19-cleaned-data-worldwide"
od.download(url)
#{"username":"kunwarakash","key":"379b6037e714cd7ad7f6d2cc137d074b"}
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kunwarakash
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 6.07M/6.07M [00:00<00:00, 11.9MB/s]

# %%
df = pd.read_csv("covid19-cleaned-data-worldwide/Covid datasets.csv")

# %%
df
# Out:
#               Date      Country  ...  New deaths  New recovered
# 0       2020-01-22  Afghanistan  ...           0              0
# 1       2020-01-23  Afghanistan  ...           0              0
# 2       2020-01-24  Afghanistan  ...           0              0
# 3       2020-01-25  Afghanistan  ...           0              0
# 4       2020-01-26  Afghanistan  ...           0              0
# ...            ...          ...  ...         ...            ...
# 206075  2022-01-22     Zimbabwe  ...           4              0
# 206076  2022-01-23     Zimbabwe  ...           2              0
# 206077  2022-01-24     Zimbabwe  ...          11              0
# 206078  2022-01-25     Zimbabwe  ...          11              0
# 206079  2022-01-26     Zimbabwe  ...           5              0
#
# [206080 rows x 8 columns]

# %%
df[ '7day_rolling_avg' ] = df["New cases"].rolling( 7).mean()

# %%
df[df.Country=="India"].Date
# Out:
# 82432    2020-01-22
# 82433    2020-01-23
# 82434    2020-01-24
# 82435    2020-01-25
# 82436    2020-01-26
#             ...
# 83163    2022-01-22
# 83164    2022-01-23
# 83165    2022-01-24
# 83166    2022-01-25
# 83167    2022-01-26
# Name: Date, Length: 736, dtype: object

# %%
import plotly.express as px
fig = px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"]["Total cases"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"]["New cases"])
#fig = px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"]['7day_rolling_avg'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"]['7day_rolling_avg'])
#px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"]["New cases"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=df[df.Country=="US"].Date, y=df[df.Country=="US"]['7day_rolling_avg'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=df[df.Country=="France"].Date, y=df[df.Country=="France"]['7day_rolling_avg'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=df[df.Country=="Germany"].Date, y=df[df.Country=="Germany"]['7day_rolling_avg'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=df[df.Country=="Russia"].Date, y=df[df.Country=="Russia"]['7day_rolling_avg'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=df[df.Country=="Pakistan"].Date, y=df[df.Country=="Pakistan"]['7day_rolling_avg'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(23,6))
plt.plot(df[df.Country=="India"].Date, df[df.Country=="India"]['7day_rolling_avg'])
plt.show()

# %%
Date = df[df.Country=="India"].Date
New_cases = df[df.Country=="India"]['7day_rolling_avg']
New_cases1 = df[df.Country=="India"]["New cases"]

# %%
px.line(df,x=Date, y=New_cases, title="India Daily New Covid Cases").update_layout(xaxis_title="Date", yaxis_title="7 day avg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ea9d6b07ace> in <module>()
# ----> 1 px.line(df,x=Date, y=New_cases, title="India Daily New Covid Cases").update_layout(xaxis_title="Date", yaxis_title="7 day avg")
#
# NameError: name 'px' is not defined

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Scatter(
    y=[3, 1, 4],
    x=["Mon", "Tue", "Wed"]))

fig.update_layout(
    title={
        'text': "Plot Title",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-b6d34c8800c9> in <module>()
# ----> 1 fig = px.line(x=df[df.Country=="India"].Date, y=df[df.Country=="India"])
#       2 fig.show()
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     260     a polyline mark in 2D space.
#     261     """
# ...

# %%
df[Country=="India"].Dat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-259eb29f9034> in <module>()
# ----> 1 df[Country=="India"].Date
#
# NameError: name 'Country' is not defined

# %%
df.Country=="India"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 206075    False
# 206076    False
# 206077    False
# 206078    False
# 206079    False
# Name: Country, Length: 206080, dtype: bool

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px


group = pd.DataFrame({'Hour': {0: 7, 1: 7, 2: 7, 3: 8, 4: 8, 5: 8},
 'Level': {0: 'H', 1: 'M', 2: 'L', 3: 'H', 4: 'M', 5: 'L'},
 'value': {0: 1.435,
  1: 3.1239999999999997,
  2: 5.577999999999999,
  3: 0.435,
  4: 2.124,
  5: 4.578}})

import plotly.graph_objects as go
fig = px.line(group, x="Hour", y="value",color='Level', title='Graph',category_orders={'Level':['H','M','L']}
             ,color_discrete_map={'H':'royalblue','M':'orange','L':'firebrick'}, line_dash='Level')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
group
# Out:
#    Hour Level  value
# 0     7     H  1.435
# 1     7     M  3.124
# 2     7     L  5.578
# 3     8     H  0.435
# 4     8     M  2.124
# 5     8     L  4.578
